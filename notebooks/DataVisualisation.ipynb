# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# import dataset
data = pd.read_csv('../dataSet/cleaned_car_data2.csv')
data.columns = data.columns.str.strip()
data.head()
# Out:
#               name manufacturer  year  age  kilometerage  engine transmission  \
# 0      Ford Fiesta         FORD  2003   22        175418  Petrol    Automatic
# 1   Vauxhall Corsa     VAUXHALL  2003   22        175418  Petrol    Automatic
# 2  Vauxhall Zafira     VAUXHALL  2003   22        175418  Petrol    Automatic
# 3      Peugeot 107      PEUGEOT  2003   22        175418  Petrol    Automatic
# 4   Vauxhall Corsa     VAUXHALL  2003   22        175418  Petrol    Automatic
#
#    price
# 0   1500
# 1   1500
# 2   1500
# 3   1500
# 4   1500

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# the most expensive cars

# %%
data.nlargest(10, 'price')
# Out:
#                          name   manufacturer  year  age  kilometerage  engine  \
# 63971             Porsche 718        PORSCHE  2022    3         12824  Petrol
# 63972            Bmw 7 Series            BMW  2024    1          7903  Hybrid
# 63961   Mercedes-Benz S-Class  MERCEDES-BENZ  2022    3         51498  Hybrid
# 63962     Bentley Continental        BENTLEY  2014   11         15771  Petrol
# 63963                 Audi R8           AUDI  2017    8         22208  Petrol
# 63964  Land Rover Range Rover     LAND ROVER  2020    5         14484  Hybrid
# 63965             Porsche 911        PORSCHE  2016    9         31382  Petrol
# 63966             Porsche 911        PORSCHE  2020    5         30899  Petrol
# 63967             Porsche 911        PORSCHE  2017    8         54717  Petrol
# 63968        Bentley Bentayga        BENTLEY  2020    5         50404  Petrol
#
#         transmission  price
# 63971      Automatic  85000
# 63972      Automatic  85000
# ...

# %% [markdown]
# cars with the most kilometers in the collection

# %%
data.nlargest(10, 'kilometerage')
# Out:
#                      name   manufacturer  year  age  kilometerage  engine  \
# 26644  Mercedes-Benz Vito  MERCEDES-BENZ  2020    5        578799  Diesel
# 7613         Toyota Yaris         TOYOTA  2019    6        500651  Diesel
# 7614       Nissan Qashqai         NISSAN  2019    6        500651  Diesel
# 7615          Nissan Juke         NISSAN  2019    6        500651  Diesel
# 7616              Audi A1           AUDI  2019    6        500651  Diesel
# 7617         Bmw 3 Series            BMW  2019    6        500651  Diesel
# 7618           Ford B-Max           FORD  2019    6        500651  Diesel
# 7619            Ford Kuga           FORD  2019    6        500651  Diesel
# 7620          Ford Fiesta           FORD  2019    6        500651  Diesel
# 7621             Fiat 500           FIAT  2019    6        500651  Diesel
#
#       transmission  price
# 26644    Automatic  18000
# 7613        Manual   6200
# 7614        Manual   6200
# 7615        Manual   6200
# ...

# %% [markdown]
# oldest cars

# %%
data.nlargest(10, 'age')
# Out:
#                          name manufacturer  year  age  kilometerage  engine  \
# 61440            Ford Mustang         FORD  1966   59         64373  Petrol
# 57638  Volkswagen Transporter   VOLKSWAGEN  1967   58          4828  Petrol
# 34068            Ford Transit         FORD  1968   57         66336  Petrol
# 50240  Volkswagen Transporter   VOLKSWAGEN  1974   51         77248  Petrol
# 63588             Porsche 911      PORSCHE  1982   43        238956  Petrol
# 63830             Porsche 911      PORSCHE  1982   43         99779  Petrol
# 63416             Porsche 911      PORSCHE  1986   39         86904  Petrol
# 61383             Porsche 911      PORSCHE  1989   36        205995  Petrol
# 63160             Porsche 911      PORSCHE  1989   36        140173  Petrol
# 63189             Porsche 911      PORSCHE  1989   36        148542  Petrol
#
#       transmission  price
# 61440       Manual  50000
# 57638       Manual  40000
# 34068    Automatic  22500
# ...

# %% [markdown]
# ### We miss our data we should see a part of it from time to an other 😅😂

# %%
data.sample(15)
# Out:
#                                        name   manufacturer  year  age  \
# 38591                      Volkswagen T-Roc     VOLKSWAGEN  2023    2
# 43701                            Honda Zr-V          HONDA  2024    1
# 37914                          Hyundai Kona        HYUNDAI  2024    1
# 51486  Volkswagen Transporter T32 Swb Diese     VOLKSWAGEN  2024    1
# 6589                            Nissan Juke         NISSAN  2010   15
# 17593                        Hyundai Tucson        HYUNDAI  2019    6
# 52873                        Nissan Qashqai         NISSAN  2024    1
# 43481                        Audi A3 Saloon           AUDI  2024    1
# 27742                          Seat Tarraco           SEAT  2019    6
# 17933                        Renault Captur        RENAULT  2021    4
# 35491                        Audi A3 Saloon           AUDI  2024    1
# 58592                               Audi Q3           AUDI  2024    1
# ...

# %% [markdown]
# Calculate and display the correlation matrix of the dataset.
#
# calculates the correlation matrix of the DataFrame `data`
# using the `corr()` method and stores it in the variable `corr`. The correlation
# matrix is a table showing correlation coefficients between variables. Each cell
# in the table shows the correlation between two variables. The value is in the
# range of -1 to 1, where 1 means highly correlated, 0 means no correlation, and
# -1 means highly negatively correlated.
#
# Returns:
#     DataFrame: A correlation matrix of the dataset.

# %%
corr = data.corr()
corr
# Out:
#                   year       age  kilometerage     price
# year          1.000000 -1.000000     -0.763895  0.595931
# age          -1.000000  1.000000      0.763895 -0.595931
# kilometerage -0.763895  0.763895      1.000000 -0.575749
# price         0.595931 -0.595931     -0.575749  1.000000

# %% [markdown]
# ### heat map

# %%
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, annot=True);
plt.savefig('../images/correlation_heatmap.png')

# %% [markdown]
# ### count of cars by car make

# %%
data['manufacturer'] = data['manufacturer'].astype(str).str.strip()
fig = plt.figure(figsize=(20, 15))
sns.countplot(y='manufacturer', data=data, order=data['manufacturer'].value_counts().index)
plt.title("Distribution of car manufacturers")
plt.xticks(rotation=90)
plt.savefig('../images/distribution-of-car-manufacturers.png')

# %% [markdown]
# top 40 cars manufacturer

# %%
data['manufacturer'] = data['manufacturer'].astype(str).str.strip()
top_40_manufacturers = data['manufacturer'].value_counts().head(40)
fig = plt.figure(figsize=(20, 15))
sns.countplot(y='manufacturer', data=data[data['manufacturer'].isin(top_40_manufacturers.index)], order=top_40_manufacturers.index)
plt.title("Distribution of Top 40 Car Manufacturers")
plt.xticks(rotation=90)
plt.savefig('../images/distribution-of-top-40-car-manufacturers.png')

# %% [markdown]
# ### numbers of cars under the various car manufacturers

# %%
data.manufacturer.value_counts()
# Out:
# AUDI             9601
# FORD             5739
# VOLKSWAGEN       5653
# BMW              4482
# MERCEDES-BENZ    3931
# VAUXHALL         3566
# TOYOTA           2924
# LAND ROVER       2720
# NISSAN           2679
# SKODA            2247
# KIA              2237
# PEUGEOT          2148
# HYUNDAI          2027
# VOLVO            1765
# RENAULT          1153
# JAGUAR           1148
# MINI             1146
# HONDA            1132
# CITROEN          1129
# SEAT              944
# FIAT              719
# MAZDA             701
# LEXUS             582
# PORSCHE           534
# MG                513
# TESLA             444
# SUZUKI            424
# CUPRA             374
# DACIA             348
# MITSUBISHI        168
# JEEP              106
# BENTLEY           103
# MERCEDES           99
# POLESTAR           90
# SMART              86
# ALFA               80
# DS                 60
# ABARTH             32
# ASTON              27
# FERRARI            26
# IVECO              24
# ...

# %% [markdown]
# ### count of cars by year

# %%
fig = plt.figure(figsize=(20,15))
sns.countplot(y='year', data=data, order=data['year'].value_counts().index)
plt.title("Distribution of cars by year")
plt.xticks(rotation=90)
plt.savefig('../images/distribution-of-car-by-year.png')

# %% [markdown]
# ### numbers of cars produced in each year

# %%
data.year.value_counts()
# Out:
# 2024    11675
# 2021     9425
# 2023     8143
# 2022     7034
# 2020     5528
# 2019     4674
# 2018     2880
# 2017     2694
# 2016     2311
# 2015     1905
# 2013     1696
# 2014     1678
# 2012     1199
# 2011      813
# 2010      747
# 2009      609
# 2008      314
# 2007      198
# 2006      161
# 2005       96
# 2002       58
# 2003       56
# 2004       33
# 1991       18
# 2001        6
# 1997        4
# 1994        3
# 1989        3
# 1998        2
# 1982        2
# 1968        1
# 1993        1
# 1974        1
# 1967        1
# 2000        1
# 1966        1
# 1986        1
# 1995        1
# Name: year, dtype: int64

# %% [markdown]
# # count of cars by engine

# %%
fig = plt.figure(figsize=(8, 5))
engine_counts = data['engine'].value_counts()
sns.barplot(y=engine_counts.index, x=engine_counts.values, palette="viridis")
plt.title("Distribution of Car Engine Type")
plt.xlabel("Count")
plt.ylabel("Engine Type")
plt.xticks(rotation=90)
plt.savefig('../images/distribution-of-car-engine-type.png')
plt.show()

# %% [markdown]
# ### numbers of cars with the different engine types

# %%
data.engine.value_counts()
# Out:
# Petrol            32167
# Diesel            17543
# Hybrid            10087
# Electric           3438
# Plug_in_hybrid      738
# Name: engine, dtype: int64

# %% [markdown]
# ### count of cars by transmission

# %%
data['transmission'] = data['transmission'].astype(str).str.strip()
fig = plt.figure(figsize=(8, 5))
transmission_counts = data['transmission'].value_counts()
sns.barplot(y=transmission_counts.index, x=transmission_counts.values, palette="viridis")
plt.title("Distribution of Car Transmissions")
plt.xlabel("Count")
plt.ylabel("Transmission Type")
plt.xticks(rotation=90)
plt.savefig('../images/distribution-of-car-transmission.png')
plt.show()

# %% [markdown]
# # number of cars with the various car transmissions

# %%
data.transmission.value_counts()
# Out:
# Automatic        26172
# Manual           24159
# Semiautomatic    13642
# Name: transmission, dtype: int64

# %% [markdown]
# ### create a pivot table to find the average price per car manufacturer

# %%
data['price_MAD'] = data['price'] * 13
pivot_table_MAD = data.pivot_table(values='price_MAD', index='manufacturer', aggfunc='mean')
result_MAD = pivot_table_MAD.sort_values('price_MAD', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(y=result_MAD.index, x=result_MAD.values.flatten(), palette="viridis")
plt.title("Average Price per Car Manufacturer in MAD", fontsize=16)
plt.xlabel("Average Price (MAD)", fontsize=14)
plt.ylabel("Manufacturer", fontsize=14)
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.savefig("../images/average_price_per_manufacturer_MAD.png")
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between the age of cars and their prices. Each point represents a car, with the color indicating the type of engine. Generally, there is a negative correlation between the age and price of cars, meaning that as cars get older, their prices tend to decrease.

# %%
engine_colors = {
    'Petrol': 'blue',
    'Diesel': 'green',
    'Hybrid': 'orange',
    'Electric': 'red',
    'Plug_in_hybrid': 'purple'
}
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='price', data=data, hue='engine', palette=engine_colors, alpha=0.7, edgecolor=None)
plt.title('Scatter Plot of Car Age vs Price', fontsize=16)
plt.xlabel('Age of Car (years)', fontsize=14)
plt.ylabel('Price of Car (£)', fontsize=14)
plt.legend(title='Engine Type')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('../images/cars_age_vs_price.png')
plt.show()

# %% [markdown]
# There is negative correlation between the age and prices of cars. As the age increases, the price reduces

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='kilometerage', y='price', data=data, hue='engine', palette=engine_colors, alpha=0.5, edgecolor=None, s=20)
plt.title('Scatter Plot of Kilometerage vs Price', fontsize=16)
plt.xlabel('Kilometerage', fontsize=14)
plt.ylabel('Price of Car (£)', fontsize=14)
plt.legend(title='Engine Type')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('../images/kilometerage_vs_price.png')
plt.show()

# %% [markdown]
# There is negative correlation between the mileage and prices of the cars. As the number of miles travelled increases, the price reduces

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='kilometerage', data=data, hue='engine', palette=engine_colors, alpha=0.7, edgecolor=None)
plt.title('Scatter Plot of Car Age vs Kilometerage', fontsize=16)
plt.xlabel('Age of Car (years)', fontsize=14)
plt.ylabel('Kilometerage', fontsize=14)
plt.legend(title='Engine Type')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('../images/age_vs_kilometerage.png')
plt.show()

# %% [markdown]
# There is a positive correlation between the mileage and age of the cars. the number of miles travelled increases with age.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='age', data=data, palette="Set2")
plt.title("Box Plot of Age", fontsize=16)
plt.xlabel("Age", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('../images/box_plot_of_age.png')
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
sns.boxplot(x="transmission", y="price", data=data, palette="Set3")
plt.title("Box Plot of Transmission vs Price", fontsize=16)
plt.xlabel("Transmission Type", fontsize=14)
plt.ylabel("Price (£)", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('../images/box_plot_of_transmission_vs_price.png')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x="engine", y="price", data=data, palette="Set3")
plt.title("Box Plot of Engine vs Price", fontsize=16)
plt.xlabel("Engine Type", fontsize=14)
plt.ylabel("Price (£)", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('../images/box_plot_of_engine_vs_price.png')
plt.show()

# %% [markdown]
# There are still outliers in the data but it's fine.

# %% [markdown]
# ## 3D bar chart for manufacturer frequency

# %%
from matplotlib import cm
summary_stats = data.describe()
print(summary_stats)

fig = plt.figure(figsize=(25, 20))
ax = fig.add_subplot(111, projection='3d')
manufacturer_counts = data["manufacturer"].value_counts()
x = np.arange(len(manufacturer_counts))
y = manufacturer_counts.values
z = np.zeros_like(x)

ax.bar(x, y, zs=z, zdir='y', alpha=0.8, color=cm.viridis(np.linspace(0, 1, len(x))))
ax.set_xticks(x)
ax.set_xticklabels(manufacturer_counts.index, rotation=45, ha="right")
ax.set_title("3D Bar Chart of Manufacturer Frequency")
ax.set_ylabel("Frequency")
ax.set_zlabel("Count")
plt.tight_layout()
plt.savefig("../images/visualizations_output.png")
plt.show()
# Out:
#                year           age   kilometerage         price
# count  63973.000000  63973.000000   63973.000000  63973.000000
# mean    2019.850390      5.149610   55984.014608  22541.530177
# std        4.094807      4.094807   51970.859282  14220.643865
# min     1966.000000      1.000000       1.609340   1500.000000
# 25%     2018.000000      2.000000   14952.377940  11192.000000
# 50%     2021.000000      4.000000   40347.763140  21189.000000
# 75%     2023.000000      7.000000   82892.275380  30990.000000
# max     2024.000000     59.000000  578799.131000  85000.000000

# %% [markdown]
# ## Visualization: Most common car names

# %%
plt.figure(figsize=(15, 8))
car_name_counts = data["name"].value_counts().head(40)
sns.barplot(y=car_name_counts.index, x=car_name_counts.values, palette="coolwarm")
plt.title("Top 20 Most Common Car Names", fontsize=16)
plt.xlabel("Count", fontsize=14)
plt.ylabel("Car Name", fontsize=14)
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.savefig("../images/car_names_visualization_head.png")
plt.show()

# %% [markdown]
# ## Visualization: Least common car names

# %%
plt.figure(figsize=(15, 8))
car_name_counts = data["name"].value_counts().tail(40)
sns.barplot(y=car_name_counts.index, x=car_name_counts.values, palette="coolwarm")
plt.title("Last 20 Least Common Car Names", fontsize=16)
plt.xlabel("Count", fontsize=14)
plt.ylabel("Car Name", fontsize=14)
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.savefig("../images/car_names_visualization_tail.png")
plt.show()
